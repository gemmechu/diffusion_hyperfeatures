# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from archs.correspondence_utils import draw_correspondences

# %%
a = np.load("dumps/pair_1095.npz", allow_pickle=True)

# %%
img1 = a["img1"]
img2 = a["img2"]

source_pts = a["source_points"]
pred_pts = a["predicted_points"]

# %%
draw_correspondences(source_pts, pred_pts, img1, img2)
# Out:
# (<Figure size 800x400 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
source_pts
# Out:
# array([[135.03836675, 162.51087646],
#        [122.63756538, 129.67844238],
#        [154.87285408, 125.08162842],
#        [104.75667248, 124.37536621],
#        [114.74040203, 119.57283936],
#        [104.78241517, 123.58187256],
#        [138.3429369 , 163.79415283],
#        [100.73099685, 122.43076172],
#        [100.92807806, 124.79615479],
#        [ 99.87587178, 121.96656494],
#        [116.91412118, 132.67042236],
#        [104.06660743, 123.18006592],
#        [124.45604211, 134.50760498],
#        [104.78115779, 123.58273926],
#        [117.48334395, 135.59177246],
#        [139.39038191, 165.97139893],
#        [118.99245574, 126.14050293],
#        [122.64884824, 128.50609131],
#        [104.16316557, 123.94731445],
#        [149.51679855, 164.47497559],
#        [156.1168522 , 125.70516357],
#        [122.98446721, 136.24023438],
#        [100.73475221, 122.43438721],
#        [154.56675832,  95.90792236],
#        [103.40374363, 123.630896  ],
# ...

# %%
pred_pts
# Out:
# array([[  0., 288.],
#        [  0., 256.],
#        [  0., 272.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 288.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 288.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 288.],
#        [  0., 272.],
#        [  0., 272.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 288.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 272.],
#        [  0., 256.],
#        [  0., 272.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 288.],
#        [  0., 272.],
#        [  0., 256.],
#        [  0., 256.],
#        [  0., 256.],
# ...

# %%
a["target_points"]
# Out:
# array([[ 72.89428031, 171.2236084 ],
#        [ 56.45819811, 133.22677002],
#        [ 95.83127007, 126.69108887],
#        [ 34.16037791, 126.83254395],
#        [ 45.36799468, 121.60093994],
#        [ 34.13599103, 125.88060303],
#        [ 76.66609509, 172.87513428],
#        [ 28.86616075, 124.53526611],
#        [ 29.26744638, 127.39620361],
#        [ 27.73252225, 123.98243408],
#        [ 49.0409738 , 137.20703125],
#        [ 33.19153172, 125.40648193],
#        [ 58.5130989 , 139.26282959],
#        [ 34.13461715, 125.88155518],
#        [ 49.92793512, 140.66477051],
#        [ 77.86727115, 175.51685791],
#        [ 51.447412  , 129.26307373],
#        [ 56.33498394, 131.89216309],
#        [ 33.37183192, 126.32593994],
#        [ 89.8020443 , 173.33428955],
#        [ 97.24135941, 127.46193848],
#        [ 56.69939441, 141.40975342],
#        [ 28.87050614, 124.54001465],
#        [ 94.32022885,  92.88667603],
#        [ 32.37861349, 125.9541626 ],
# ...

# %%
img1.shape
# Out:
# (256, 256, 3)
