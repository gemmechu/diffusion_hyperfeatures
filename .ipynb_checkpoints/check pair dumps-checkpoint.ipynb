# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from archs.correspondence_utils import draw_correspondences_correspondences

# %%
a = np.load("dumps/pair_0.npz", allow_pickle=True)

# %%
img1 = a["img1"]
img2 = a["img2"]

source_pts = a["source_points"]
pred_pts = a["predicted_points"]

# %%
draw_correspondences(source_pts[::50], pred_pts[::50], img1, img2)
# Out:
# (<Figure size 800x400 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
source_pts[::50].shape
# Out:
# (14, 2)

# %%
source_pts.shape
# Out:
# (690, 2)
